# %% [markdown]
# # ¿Qué es el Análisis Exploratorio de los Datos?

# %% [markdown]
# `El Análisis Exploratorio de Datos (EDA)` es un proceso fundamental en el ámbito de la ciencia de datos, donde se aplican técnicas estadísticas y visuales para examinar y comprender la naturaleza de los datos. Este proceso no solo permite garantizar la objetividad e interoperabilidad de los datos, sino que también abre las puertas a un sinfín de descubrimientos valiosos.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# El `EDA` se asemeja a una expedición a través de un territorio desconocido, donde cada paso nos acerca a comprender mejor los datos. A través de esta exploración, podemos:
#
# - `Identificar y corregir errores:` Detectar posibles errores en la recolección o el ingreso de datos, asegurando la confiabilidad de la información.
# - `Desenmascarar valores atípicos:` Descubrir valores anormales que podrían distorsionar los análisis, permitiendo una mejor interpretación de los datos.
# - `Desvelar relaciones ocultas:` Explorar las correlaciones entre variables, revelando patrones y tendencias que podrían pasar desapercibidos.
# - `Eliminar redundancias:` Identificar variables redundantes o irrelevantes, optimizando el análisis y obteniendo resultados más precisos.
# - `Visualizar lo invisible:` Transformar datos complejos en gráficos claros y concisos, facilitando la comprensión y la comunicación de los hallazgos.

# %% [markdown]
# El `EDA` se utiliza en una amplia variedad de campos, incluyendo la ciencia, la ingeniería, la medicina, los negocios y las ciencias sociales. Es una herramienta esencial para cualquier científico de datos o analista que trabaje con conjuntos de datos.
#
# Existen diversas técnicas para realizar un `EDA`, algunas de las más comunes son:
#
# - `Descripción de las variables:` Se describe el tipo de variable (numérica, categórica), las medidas de resumen (media, mediana, moda, desviación estándar) y la distribución de la variable.
# - `Visualización de datos:` Se utilizan gráficos y diagramas para visualizar la distribución de las variables, las relaciones entre ellas y la presencia de valores atípicos. Algunos ejemplos de gráficos comunes son histogramas, diagramas de dispersión, gráficos de barras y mapas de calor.
# - `Análisis de relaciones:` Se exploran las relaciones entre las variables utilizando medidas de correlación y asociación.
# Detección de anomalías: Se identifican valores atípicos o inusuales en el conjunto de datos.
# - `Transformación de datos:` Se transforman las variables si es necesario para mejorar su distribución o facilitar el análisis.

# %% [markdown]
# `Beneficios del EDA:`
#
# - `Mejora la comprensión de los datos:` El EDA permite a los analistas comprender mejor las características de los datos, lo que puede ser útil para identificar patrones importantes, detectar errores y tomar decisiones informadas.
# - `Facilita el modelado de datos:` Un buen EDA puede ayudar a preparar los datos para el modelado de datos, lo que puede mejorar la precisión y el rendimiento de los modelos.
# - `Ayuda a comunicar los resultados:` Los gráficos y diagramas generados durante el EDA pueden ser utilizados para comunicar los resultados de manera efectiva a otras personas.

# %% [markdown]
# # Preparación y configuración del entorno de trabajo

# %% [markdown]
# ## Ficha Técnica

# %% [markdown]
# `Resultados anonimizados de las pruebas de Saber 11 de los años 2018, 2019 y 2020.`
#
# `Información General:`
#
# - Fuente de datos: Acumulado Saber 11, unión de los resultado de los años 2018, 2019 y 2020
# - Fecha de creación: 15 de abril de 2024
# - Filas: 1.086.317
# - Columnas: 40
#
# Información de la entidad:
#
# - Área o dependencia: Oficina Asesora de Planeación
# - Nombre de la entidad: Instituto Colombiano para la Evaluación de la Educación
# - Departamento: Bogotá D.C.
# - Municipio: Bogotá D.C.
# - Orden: Nacional
# - Sector: Educación
#
# Información del conjunto de datos:
#
# - Idioma: Español
# - URL de documenación: http://www.icfes.gov.co/investigadores-y-estudiantes-posgrado/acceso-a-bases-de-datos
# - URL de normativa: http://www.icfes.gov.co/normatividad
#
# Temas:
#
# - Categoría: Educación
# - Etiquetas: `pruebas icfes`,`icfes`,`saber 11`,`resultados`

# %% [markdown]
# ## Conexión y consulta a la fuente de datos

# %%
# Importar librerias

import os
import altair as alt
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pyodbc
import warnings
import sqlite3

# %%
try:
    # Leer el archivo CSV ubicado en la ruta especificada y asigna los datos a la variable df_resultados
    df_acumulado_saber_11 = pd.read_csv('C:/Users/espit/OneDrive/Documentos/Cymetria Bootcamps/AVDV3-219/Modulo_2-Estadistica_y_Modelado_Matematico_Avanzado/acumulado_saber_11.csv')

    # Si la lectura del archivo es exitosa, imprime un mensaje indicando que el dataset se cargó correctamente
    print("El dataset se cargó exitosamente.")

# Si se produce un error específico de "FileNotFoundError" (archivo no encontrado), ejecuta este bloque de código
except FileNotFoundError as e:
    
    # Imprime un mensaje de error personalizado indicando que el archivo no se pudo encontrar, junto con los detalles específicos del error
    print(f"Error: El archivo no se pudo encontrar. Detalles: {e}")

# Si se produce cualquier otro tipo de error, ejecuta este bloque de código
except Exception as e:
    
    # Imprime un mensaje de error genérico indicando que ocurrió un error inesperado, junto con los detalles específicos del error
    print(f"Error inesperado: {e}")
# Out:
# C:\Users\espit\AppData\Local\Temp\ipykernel_6972\991876861.py:3: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_acumulado_saber_11 = pd.read_csv('C:/Users/espit/OneDrive/Documentos/Cymetria Bootcamps/AVDV3-219/Modulo_2-Estadistica_y_Modelado_Matematico_Avanzado/acumulado_saber_11.csv')
# El dataset se cargó exitosamente.

# %% [markdown]
# # Diccionario de datos

# %% [markdown]
# En el mundo actual, donde los datos se han convertido en un activo crucial para las organizaciones, la gestión eficaz de la información es fundamental para el éxito. Un componente esencial de esta gestión es el diccionario de datos, una herramienta que proporciona una base de datos centralizada para almacenar y organizar información detallada sobre los elementos de datos utilizados en una organización.

# %% [markdown]
# `¿Qué es un diccionario de datos?`
#
# Un diccionario de datos funciona como un repositorio centralizado que almacena información descriptiva sobre cada elemento de datos utilizado en un sistema o conjunto de datos. Esta información incluye:
#
# - Nombre del elemento de dato: Un identificador único para cada elemento de datos.
# - Descripción del elemento de dato: Una explicación detallada de lo que significa el elemento de datos y cómo se utiliza.
# - Tipo de dato: El formato en que se almacena el dato (por ejemplo, número, texto, fecha).
# - Longitud del dato: La cantidad máxima de caracteres o bytes que puede contener el dato.
# - Origen del dato: De dónde proviene el dato (por ejemplo, una base de datos, un sensor, una entrada manual).
# - Uso del dato: Cómo se utiliza el dato en el sistema (por ejemplo, para cálculos, informes, toma de decisiones).
# - Reglas de negocio: Cualquier restricción o condición que se aplique al dato (por ejemplo, valores válidos, rangos permitidos).
# - Propietario del dato: La persona o equipo responsable de la calidad y la integridad del dato.
# - Beneficios del diccionario de datos:
#
# `Un diccionario de datos bien mantenido ofrece numerosos beneficios para las organizaciones, incluyendo:`
#
# - Mejora la comunicación y la colaboración: Al proporcionar una fuente única de información sobre los datos, los diccionarios de datos ayudan a que las personas que trabajan con los datos se entiendan mejor y colaboren de manera más eficaz.
# - Garantiza la calidad de los datos: Los diccionarios de datos pueden ayudar a identificar y corregir errores en los datos, así como a garantizar que los datos sean consistentes y precisos.
# - Facilita el uso de los datos: Los diccionarios de datos pueden hacer que los datos sean más fáciles de encontrar, comprender y utilizar para las personas que necesitan acceder a ellos.
# - Cumplimiento de regulaciones: Los diccionarios de datos pueden ayudar a las organizaciones a cumplir con las regulaciones que requieren que documenten y protejan sus datos.
#
# `¿Cómo se utiliza un diccionario de datos?`
#
# Los diccionarios de datos se utilizan de diversas maneras, incluyendo:
#
# - Documentación de nuevos conjuntos de datos: Cuando se crea un nuevo conjunto de datos, el diccionario de datos se puede utilizar para documentar la estructura, los elementos de datos y las relaciones del conjunto de datos.
# - Búsqueda de información sobre elementos de datos: Los usuarios pueden consultar el diccionario de datos para encontrar información sobre un elemento de datos específico, como su definición, tipo de dato, origen y uso.
# - Análisis de impacto de cambios: Cuando se realizan cambios en un sistema o conjunto de datos, el diccionario de datos se puede utilizar para identificar qué elementos de datos se verán afectados y cómo.
# - Cumplimiento de regulaciones: El diccionario de datos se puede utilizar para demostrar a los auditores que la organización cumple con las regulaciones que requieren que documenten y protejan sus datos.

# %% [markdown]
# # Relación entre el Análisis Exploratorio de Datos (EDA) y el Perfilamiento de Datos: Conceptos y Conexión

# %% [markdown]
# Objetivo: Comprender mejor las características, calidad y relaciones dentro del conjunto de datos de 1,086,317 entradas y 40 columnas que contienen información sobre estudiantes, datos demográficos, puntajes y características familiares. El análisis exploratorio y el perfilamiento de datos identificarán posibles problemas de calidad, patrones, tendencias, y permitirán extraer insights valiosos.

# %% [markdown]
# Al llegar un archivo, lo primero que deberíamos hacer es intentar responder:
#
# `¿Cuántos registros hay?`
# - ¿Son demasiado pocos?
# - ¿Son muchos y no tenemos Capacidad (CPU+RAM) suficiente para procesarlo?
#
# `¿Están todas las filas completas ó tenemos campos con valores nulos?`
# - En caso que haya demasiados nulos: ¿Queda el resto de información inútil?
#
# `¿Que datos son discretos y cuales continuos?`
# - Muchas veces sirve obtener el tipo de datos: texto, int, double, float
#
# `¿Cuales parecen ser features importantes? ¿Cuáles podemos descartar?`
# - ¿Siguen alguna distribución?
# - ¿Hay correlación entre features (características)?
#
# `¿Cuales son los Outliers? (unos pocos datos aislados que difieren drásticamente del resto y “contaminan” ó desvían las distribuciones)`
# - ¿Podemos eliminarlos? es ¿importante conservarlos?
#
# `¿Tenemos posible sesgo de datos? (por ejemplo perjudicar a clases minoritarias por no incluirlas y que el modelo de ML discrimine)`
# - Puede ocurrir que tengamos set de datos incompletos y debamos pedir a nuestro cliente/proveedor ó interesado que nos brinde mayor información de los campos, que aporte más conocimiento ó que corrija campos.

# %% [markdown]
# ## Análisis Exploratorio de los Datos (EDA)

# %% [markdown]
# El Análisis Exploratorio de Datos (EDA, por sus siglas en inglés) es un conjunto de técnicas estadísticas y visuales que se utilizan para comprender mejor un conjunto de datos antes de aplicar cualquier modelo predictivo o realizar análisis más profundos. Su propósito es ayudar a:
#
# El Análisis Exploratorio de Datos (EDA, por sus siglas en inglés) es un conjunto de técnicas estadísticas y visuales que se utilizan para comprender mejor un conjunto de datos antes de aplicar cualquier modelo predictivo o realizar análisis más profundos. Su propósito es ayudar a:
#
# - Describir las características fundamentales de los datos, como su distribución, tendencias, y variabilidad.
# - Detectar valores atípicos (outliers) que puedan influir en el análisis.
# - Identificar patrones o relaciones entre variables (como correlaciones).
# - Evaluar la calidad de los datos, identificando datos faltantes o inconsistencias.
#
# El EDA normalmente se realiza mediante gráficos como histogramas, diagramas de dispersión, gráficos de cajas (boxplots), y estadísticas descriptivas, tales como la media, mediana, desviación estándar, etc.
#
# `Librerías para Análisis Exploratorio de Datos (EDA):`
#
# - Pandas:
#     - Biblioteca esencial para el manejo de datos. Te permite cargar, manipular y analizar datos fácilmente.
#     - Funciones útiles: .describe(), .info(), .value_counts(), etc.
#
# - Matplotlib:
#     - Biblioteca para la creación de gráficos básicos y avanzados.
#     - Útil para crear gráficos como histogramas, gráficos de dispersión, gráficos de barras, etc.
#
# - Seaborn:
#     - Biblioteca basada en Matplotlib que facilita la creación de gráficos estadísticos.
#     - Útil para visualizaciones como gráficos de caja (boxplots), gráficos de correlación, gráficos de distribución, entre otros.
#
# - Plotly:
#     - Biblioteca para crear gráficos interactivos y visualizaciones avanzadas.
#     - Ideal para explorar los datos de manera interactiva.
#
# - NumPy:
#     - Biblioteca para el manejo de arrays y operaciones matemáticas avanzadas.
#     - Es útil en el EDA para cálculos estadísticos o manejo de datos numéricos.

# %% [markdown]
# ## Perfilamiento de Datos

# %% [markdown]
# El perfilamiento de datos es el proceso de analizar las características fundamentales de un conjunto de datos con el objetivo de evaluar su calidad y comprender su estructura. Incluye la recopilación de información detallada sobre cada variable o columna de los datos, como:
#
# - Tipos de datos (numéricos, categóricos, etc.).
# - Valores únicos (distintos), como cuántos y cuáles son.
# - Frecuencia de valores (cuántas veces aparece cada valor en una columna).
# - Valores faltantes o incompletos.
# - Valores atípicos o anómalos.
#
# El perfilamiento de datos a menudo es el primer paso en un análisis de calidad de datos, ya que permite entender el estado y estructura de los datos antes de realizar cualquier transformación o limpieza.
#
# `Librerías para Perfilamiento de Datos:`
#
# - Pandas Profiling:
#     - Genera reportes detallados sobre las características de los datos. Automáticamente crea un perfil detallado que incluye estadísticas descriptivas, visualización de datos, valores faltantes, etc.
#
# - Sweetviz:
#     - Similar a Pandas Profiling, genera reportes exploratorios interactivos de los datos con visualizaciones detalladas.
#
# - DataPrep:
#     - Es una biblioteca diseñada para realizar el perfilamiento de datos de manera rápida, generando reportes con información de calidad, estadísticas y gráficos interactivos.
#
# - Great Expectations:
#     - Biblioteca diseñada para el perfilamiento y validación de datos, con el objetivo de garantizar la calidad y consistencia de los datos.

# %% [markdown]
# ## Relación entre EDA y Perfilamiento de Datos

# %% [markdown]
# - Complementarios: El perfilamiento de datos es una técnica dentro del EDA, ya que ambos procesos se enfocan en la comprensión preliminar de los datos. El perfilamiento es más específico y técnico, con el objetivo de evaluar la calidad y las características de los datos. Por otro lado, el EDA es un enfoque más amplio que también incluye la visualización y la detección de patrones o relaciones entre las variables.
#
# - Secuencia: El perfilamiento de datos suele ser uno de los primeros pasos del EDA. Proporciona una vista detallada y técnica sobre la calidad y estructura de los datos, mientras que el EDA da un panorama más general y visual de las propiedades de los datos.
#
# Ambos procesos son esenciales para asegurar que los datos sean apropiados para un análisis más avanzado o modelado predictivo.

# %%
# Proporción de valores faltantes
missing_values_percentage = df_acumulado_saber_11.isnull().mean()*100
missing_values_count = df_acumulado_saber_11.isnull().sum()

# Crear un DataFrame con la cantidad y el porcentaje de valores faltantes
missing_data = pd.DataFrame({
    'Cantidad': missing_values_count,
    'Porcentaje': missing_values_percentage
})

# Visualizar las columnas con mayor porcentaje de valores faltantes
plt.figure(figsize=(18, 4))
ax = sns.barplot(x=missing_data.index, y=missing_data['Porcentaje'])

# Añadir los valores de cantidad y porcentaje encima de las barras
for i, (count, perc) in enumerate(zip(missing_data['Cantidad'], missing_data['Porcentaje'])):
    ax.text(i, perc + 1, f'{count} ({perc:.1f}%)', ha='center', va='bottom', fontsize=9)

plt.xticks(rotation= 90)
plt.title("Titulo")
plt.ylabel("Porcentaje")
plt.show()

# %%
# Proporción de valores faltantes
missing_values = df_acumulado_saber_11.isnull().mean()*100

plt.figure(figsize=(18, 4))
sns.barplot(x=missing_values.index, y=missing_values)
plt.xticks(rotation= 90)
plt.title("Titulo")
plt.ylabel("Porcentaje")
plt.show()

# %%
# Establecer el tamaño de la figura
plt.figure(figsize=(18, 6))  # Ajusta el tamaño aquí (más largo y ancho)

# Boxplot para comparar puntajes por estrato de vivienda
sns.boxplot(x='FAMI_ESTRATOVIVIENDA', y='PUNT_GLOBAL', data=df_acumulado_saber_11)

# Título del gráfico
plt.title("Puntaje global por estrato", fontsize=16)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Despliegue Técnico EDA

# %%
# Se crea un DataFrame nuevo, utilizando los datos existentes del dataset
df_acumulado_saber_11 = pd.DataFrame(df_acumulado_saber_11)

# Consulta y validación de la cantidad de filas y columnas del dataframe
num_rows, num_cols = df_acumulado_saber_11.shape

# Imprimir mensaje y valores de salidas del dataframe
print(f'El DataFrame, tiene {num_rows} filas y {num_cols} columnas.')
# Out:
# El DataFrame, tiene 1086317 filas y 40 columnas.

# %%
df_acumulado_saber_11.head(5)
# Out:
#   ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  PERIODO  ESTU_CONSECUTIVO  \
# 0                 CC          COLOMBIA           F    20181  SB11201810007354
# 1                 TI          COLOMBIA           M    20181  SB11201810018765
# 2                 TI          COLOMBIA           M    20181  SB11201810028523
# 3                 TI          COLOMBIA           F    20181  SB11201810003574
# 4                 TI          COLOMBIA           F    20181  SB11201810024346
#
#   ESTU_PAIS_RESIDE ESTU_TIENEETNIA ESTU_DEPTO_RESIDE ESTU_MCPIO_RESIDE  \
# 0         COLOMBIA              No            BOGOTA       BOGOTÁ D.C.
# 1         COLOMBIA              No             VALLE              CALI
# 2         COLOMBIA              No             VALLE              CALI
# 3         COLOMBIA              No             VALLE              CALI
# 4         COLOMBIA              No             VALLE              CALI
#
#   FAMI_ESTRATOVIVIENDA  ... COLE_AREA_UBICACION COLE_JORNADA  \
# ...

# %%
df_acumulado_saber_11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1086317 entries, 0 to 1086316
# Data columns (total 40 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   ESTU_TIPODOCUMENTO            1086317 non-null  object
#  1   ESTU_NACIONALIDAD             1086317 non-null  object
#  2   ESTU_GENERO                   1086308 non-null  object
#  3   PERIODO                       1086317 non-null  int64
#  4   ESTU_CONSECUTIVO              1086317 non-null  object
#  5   ESTU_PAIS_RESIDE              1086317 non-null  object
#  6   ESTU_TIENEETNIA               1082560 non-null  object
#  7   ESTU_DEPTO_RESIDE             1085174 non-null  object
#  8   ESTU_MCPIO_RESIDE             1085174 non-null  object
#  9   FAMI_ESTRATOVIVIENDA          1067781 non-null  object
#  10  FAMI_PERSONASHOGAR            1061274 non-null  object
#  11  FAMI_CUARTOSHOGAR             1062621 non-null  object
# ...

# %%
df_acumulado_saber_11.describe()
# Out:
#             PERIODO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# count  1.086317e+06          1.086317e+06      1.086317e+06      1.086317e+06
# mean   2.019851e+04          5.238752e+01      5.102646e+01      4.848017e+01
# std    5.469084e+00          1.047043e+01      1.198036e+01      1.081123e+01
# min    2.018100e+04          0.000000e+00      0.000000e+00      0.000000e+00
# 25%    2.019400e+04          4.500000e+01      4.200000e+01      4.000000e+01
# 50%    2.019400e+04          5.300000e+01      5.100000e+01      4.800000e+01
# 75%    2.020400e+04          6.000000e+01      5.900000e+01      5.600000e+01
# max    2.020400e+04          1.000000e+02      1.000000e+02      1.000000e+02
#
#        PUNT_SOCIALES_CIUDADANAS   PUNT_INGLES   PUNT_GLOBAL  ANIO_NACIMIENTO
# count              1.086317e+06  1.085928e+06  1.086317e+06     1.086317e+06
# mean               4.746889e+01  4.817472e+01  2.485626e+02     2.003829e+03
# ...

# %%
df_acumulado_saber_11.columns
# Out:
# Index(['ESTU_TIPODOCUMENTO', 'ESTU_NACIONALIDAD', 'ESTU_GENERO', 'PERIODO',
#        'ESTU_CONSECUTIVO', 'ESTU_PAIS_RESIDE', 'ESTU_TIENEETNIA',
#        'ESTU_DEPTO_RESIDE', 'ESTU_MCPIO_RESIDE', 'FAMI_ESTRATOVIVIENDA',
#        'FAMI_PERSONASHOGAR', 'FAMI_CUARTOSHOGAR', 'FAMI_EDUCACIONPADRE',
#        'FAMI_EDUCACIONMADRE', 'FAMI_TRABAJOLABORPADRE',
#        'FAMI_TRABAJOLABORMADRE', 'FAMI_TIENEINTERNET', 'FAMI_TIENECOMPUTADOR',
#        'FAMI_TIENECONSOLAVIDEOJUEGOS', 'FAMI_NUMLIBROS',
#        'FAMI_SITUACIONECONOMICA', 'ESTU_DEDICACIONLECTURADIARIA',
#        'ESTU_DEDICACIONINTERNET', 'ESTU_HORASSEMANATRABAJA',
#        'ESTU_TIPOREMUNERACION', 'COLE_NOMBRE_ESTABLECIMIENTO', 'COLE_GENERO',
#        'COLE_NATURALEZA', 'COLE_BILINGUE', 'COLE_CARACTER',
#        'COLE_AREA_UBICACION', 'COLE_JORNADA', 'ESTU_PRIVADO_LIBERTAD',
#        'PUNT_LECTURA_CRITICA', 'PUNT_MATEMATICAS', 'PUNT_C_NATURALES',
#        'PUNT_SOCIALES_CIUDADANAS', 'PUNT_INGLES', 'PUNT_GLOBAL',
# ...

# %% [markdown]
# Siguiendo la metodología de [Pedro Marcelino](https://www.kaggle.com/pmarcelino), basada en el capítulo ['Examining Your Data' de Hair et al. (2013)](https://www.amazon.com/gp/product/9332536503/), realizaré un análisis exhaustivo del conjunto de datos. Este análisis tiene como objetivo brindar información valiosa sobre el comportamiento de los resultados de las pruebas ICFES que comprende los periodos: 2018, 2019 y 2020
#
# Dividiré el análisis en los siguientes componentes:
#
# 1. Comprender el problema: Una revisión inicial del problema y de los objetivos de la investigación.
# 2. Análisis univariable: Examen de las características individuales del conjunto de datos.
# 3. Análisis multivariable: Exploración de las relaciones entre múltiples variables.
# 4. Limpieza básica de los datos: Identificación y manejo de valores atípicos, datos faltantes y otros problemas de calidad de los datos.
# 5. Verificación de supuestos: Evaluación de los supuestos necesarios para el modelo y la metodología de análisis seleccionada.

# %% [markdown]
# ## Comprensión del problema

# %% [markdown]
# El conjunto de datos, proporciona información sobre estudiantes colombianos, incluyendo aspectos socioeconómicos, educativos y de rendimiento académico. A partir de este conjunto, podemos realizar diversas exploraciones y análisis para comprender mejor las características de los estudiantes y obtener información valiosa para la toma de decisiones en el ámbito educativo.
#
# `Aspectos socioeconómicos:`
#
# - Tipo de documento de identidad: El conjunto de datos incluye información sobre el tipo de documento de identidad de los estudiantes, lo cual permite identificar la presencia de estudiantes extranjeros o con estatus migratorio especial.
#
# - Nacionalidad: Se registra la nacionalidad de los estudiantes, lo que permite analizar la diversidad poblacional en el sistema educativo.
#
# - Género: Se identifica el género de los estudiantes, permitiendo estudiar posibles brechas de género en el acceso a la educación y el rendimiento académico.
#
# - Estrato socioeconómico: El estrato socioeconómico de la familia del estudiante es un indicador importante de su nivel de ingresos y acceso a recursos, lo cual puede influir en su trayectoria educativa.
#
# - Composición del hogar: Se registra el número de personas que viven en el hogar del estudiante, así como el número de cuartos, lo que aporta información sobre las condiciones habitacionales y el potencial apoyo familiar en el proceso educativo.
#
# - Nivel educativo de los padres: El nivel educativo de los padres puede ser un factor determinante en las expectativas y el apoyo que reciben los estudiantes en su educación.
#
# - Empleo de los padres: La información sobre el empleo de los padres permite analizar la disponibilidad de tiempo y recursos que estos pueden dedicar al seguimiento del proceso educativo de sus hijos.
#
# - Acceso a internet, computador y consola de videojuegos: Se registra si la familia del estudiante tiene acceso a internet, computador y consola de videojuegos, elementos que pueden ser considerados como herramientas de apoyo para el aprendizaje.
#
# - Situación económica: La situación económica de la familia se categoriza como "Igual", "Mejor", "Peor" o "No sabe", lo cual permite identificar posibles dificultades económicas que podrían afectar el desempeño académico de los estudiantes.
#
#
# `Aspectos educativos:`
#
# - Institución educativa: Se registra el nombre, género, naturaleza (oficial o no oficial), bilingüismo, carácter (académico o técnico/académico), área de ubicación (urbano o rural) y jornada escolar de la institución educativa a la que asiste el estudiante. Esta información permite analizar la diversidad de instituciones educativas presentes en el conjunto de datos y su potencial impacto en el rendimiento académico.
#
# - Dedicación a la lectura y el internet: Se registra el tiempo diario que el estudiante dedica a la lectura y al uso del internet, lo cual permite evaluar sus hábitos de estudio y acceso a la información.
#
# - Horas semanales de trabajo: Se registra el número de horas semanales que el estudiante dedica a trabajar, lo cual puede ser un indicador de la necesidad de trabajar para contribuir al sustento familiar y su posible impacto en el tiempo disponible para el estudio.
#
# - Tipo de remuneración: Se registra el tipo de remuneración que recibe el estudiante por su trabajo, lo cual puede aportar información sobre su nivel de ingresos y las condiciones laborales en las que se desempeña.
#
# `Rendimiento académico:`
#
# - Puntajes en pruebas de lectura crítica, matemáticas, ciencias naturales, sociales y ciudadanas, inglés y global: Se registran los puntajes obtenidos por los estudiantes en estas pruebas, lo cual permite evaluar su desempeño académico en diferentes áreas del conocimiento.
#
# - Año de nacimiento: El año de nacimiento de los estudiantes permite analizar el rendimiento académico en función de la cohorte o edad generacional.
#
# `Análisis y observaciones potenciales:`
#
# A partir de la exploración y análisis de este conjunto de datos, se pueden obtener valiosas conclusiones sobre las características de los estudiantes colombianos, las condiciones socioeconómicas en las que se encuentran y su rendimiento académico. Esta información puede ser utilizada para:
#
# - Identificar brechas de género, socioeconómicas o educativas que afectan el acceso y la calidad de la educación.
# - Diseñar e implementar políticas públicas y programas educativos focalizados en las necesidades específicas de diferentes grupos de estudiantes.
# - Evaluar la efectividad de las intervenciones educativas y realizar seguimiento a los indicadores de rendimiento académico.
# Promover la equidad y la inclusión en el sistema educativo colombiano.
#
# `Nota:`
#
# Es importante destacar que este análisis es preliminar y que se requerirían estudios más profundos para comprender en detalle las relaciones entre las variables y los factores que inciden en el rendimiento académico de los estudiantes colombianos.

# %% [markdown]
# ## Análisis univariable

# %% [markdown]
# El análisis univariable es una técnica estadística que se utiliza para estudiar y describir las características de una sola variable dentro de un conjunto de datos. Es un paso fundamental en el análisis exploratorio de datos y permite obtener una comprensión básica de la distribución, tendencia central, dispersión y valores atípicos de la variable en cuestión.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# `Las principales técnicas de análisis univariable incluyen:`
#
# - Medidas de tendencia central: Media, mediana, moda.
# - Medidas de dispersión: Rango, desviación estándar, varianza.
# - Análisis de frecuencias: Tablas de frecuencias, gráficos de barras o pie.
# - Representaciones gráficas: Histogramas, diagramas de cajas, diagramas de dispersión.
#
# `El análisis univariable es útil para:`
#
# - Identificar la estructura básica de la variable.
# - Resumir las características principales de la variable.
# - Explorar la distribución de la variable.
# - Detectar valores atípicos o inusuales.
# - Preparar el terreno para análisis multivariantes más complejos.
#
# En el contexto del conjunto de datos sobre estudiantes colombianos que hemos discutido, el análisis univariable puede ser utilizado para:
#
# - Analizar la distribución de las variables socioeconómicas, como el estrato socioeconómico, el nivel educativo de los padres y el acceso a internet.
# - Estudiar la distribución de las variables educativas, como la institución educativa a la que asiste el estudiante y las horas semanales de trabajo.
# - Examinar la distribución de los puntajes en las pruebas de rendimiento académico.
# - Identificar posibles relaciones entre las variables.
#
# `Nota:` Es importante destacar que el análisis univariable es solo un primer paso en el proceso de análisis de datos. Para obtener una comprensión más profunda de las relaciones entre las variables y los factores que inciden en el rendimiento académico de los estudiantes colombianos, se requerirían análisis multivariantes más complejos.

# %% [markdown]
# ### Análisis descriptivo de variables cuantitativas

# %%
# Medidas de tendencia central
print('Media:')
print(df_acumulado_saber_11.describe().loc['mean'])
# Out:
# Media:
# PERIODO                     20198.510093
# PUNT_LECTURA_CRITICA           52.387521
# PUNT_MATEMATICAS               51.026465
# PUNT_C_NATURALES               48.480166
# PUNT_SOCIALES_CIUDADANAS       47.468894
# PUNT_INGLES                    48.174723
# PUNT_GLOBAL                   248.562611
# ANIO_NACIMIENTO              2003.828766
# Name: mean, dtype: float64

# %% [markdown]
# - Puntuación promedio global moderada: La media global de las pruebas (PUNT_GLOBAL) es de 248.56 puntos sobre 500, lo que indica un rendimiento promedio de los estudiantes en las diferentes áreas evaluadas. Se podría profundizar en el análisis para identificar las áreas de mayor y menor fortaleza.
#
# - Desigualdad en las puntuaciones por área: Se observa una variación en las medias de las pruebas por área, siendo la más alta en PUNT_LECTURA_CRITICA (52.38 puntos) y la más baja en PUNT_SOCIALES_CIUDADANAS (47.47 puntos). Esta diferencia podría estar relacionada con factores como la metodología de las pruebas, el enfoque educativo en las instituciones o las preferencias e intereses de los estudiantes.

# %%
# Medidas de dispersión
print(df_acumulado_saber_11.describe().loc['std'])
# Out:
# PERIODO                      5.469084
# PUNT_LECTURA_CRITICA        10.470425
# PUNT_MATEMATICAS            11.980357
# PUNT_C_NATURALES            10.811234
# PUNT_SOCIALES_CIUDADANAS    12.248236
# PUNT_INGLES                 12.541234
# PUNT_GLOBAL                 51.070141
# ANIO_NACIMIENTO              2.848742
# Name: std, dtype: float64

# %% [markdown]
# - Variabilidad moderada en el rendimiento académico: La desviación estándar relativamente baja en las pruebas por área (excepto PUNT_SOCIALES_CIUDADANAS y PUNT_INGLES) indica una variabilidad moderada en el rendimiento académico de los estudiantes. Esto sugiere que la mayoría de los estudiantes se encuentran dentro de un rango de puntajes relativamente cercano a la media.
#
# - Mayor dispersión en puntajes de Ciencias Sociales y Ciudadanas e Inglés: Las desviaciones estándar más altas en PUNT_SOCIALES_CIUDADANAS (12.25 puntos) y PUNT_INGLES (12.54 puntos) revelan una mayor dispersión en los puntajes de estas áreas. Esto podría estar relacionado con la complejidad de las materias, la metodología de las pruebas o las diferentes metodologías de enseñanza.

# %%
#Top 5 departamentos con puntajes globales más altos:

top5_departamentos = df_acumulado_saber_11.groupby('ESTU_DEPTO_RESIDE')['PUNT_GLOBAL'].mean().nlargest(5)
top5_departamentos
# Out:
# ESTU_DEPTO_RESIDE
# BOGOTA             301.656117
# BOGOTÁ             267.812190
# SANTANDER          264.640827
# BOYACA             261.110662
# NORTE SANTANDER    255.641275
# Name: PUNT_GLOBAL, dtype: float64

# %%
# Reemplazar valores de registros de ESTU_DEPTO_RESIDE

# Crear un diccionario
replace_dict ={
            'BOGOTA' : 'BOGOTÁ'
}

# Implementar la función .replace
df_acumulado_saber_11['ESTU_DEPTO_RESIDE'].replace(replace_dict, inplace=True)

# %%
#Top 5 departamentos con puntajes globales más altos:

top5_departamentos = df_acumulado_saber_11.groupby('ESTU_DEPTO_RESIDE')['PUNT_GLOBAL'].mean().nlargest(10)
top5_departamentos
# Out:
# ESTU_DEPTO_RESIDE
# BOGOTÁ             268.888704
# SANTANDER          264.640827
# BOYACA             261.110662
# NORTE SANTANDER    255.641275
# CUNDINAMARCA       255.509488
# QUINDIO            253.401475
# RISARALDA          252.580878
# VALLE              251.098755
# HUILA              250.180658
# CALDAS             249.322829
# Name: PUNT_GLOBAL, dtype: float64

# %%
# Calcular los 5 departamentos con puntajes globales más altos
top5_departamentos = df_acumulado_saber_11.groupby('ESTU_DEPTO_RESIDE')['PUNT_GLOBAL'].mean().nlargest(5).index

# Filtrar los datos para incluir solo los departamentos del top 5
datos_top5_departamentos = df_acumulado_saber_11[df_acumulado_saber_11['ESTU_DEPTO_RESIDE'].isin(top5_departamentos)]

# Agrupar datos por periodo y departamento de residencia
punt_global_por_periodo_depto = datos_top5_departamentos.groupby(['PERIODO','ESTU_DEPTO_RESIDE'])['PUNT_GLOBAL'].mean().reset_index()

# Crear la línea de tiempo
plt.figure(figsize=(14, 8))

# Usar una paleta de colores más atractiva
palette = sns.color_palette("coolwarm", len(top5_departamentos))

# Crear la línea de tiempo con puntos y etiquetas de valor
sns.lineplot(x='PERIODO', y='PUNT_GLOBAL', hue='ESTU_DEPTO_RESIDE', data=punt_global_por_periodo_depto, palette=palette, marker='o')

# Añadir etiquetas de valor a cada punto
for line in range(0, punt_global_por_periodo_depto.shape[0]):
    plt.text(punt_global_por_periodo_depto.PERIODO[line], punt_global_por_periodo_depto.PUNT_GLOBAL[line],
             round(punt_global_por_periodo_depto.PUNT_GLOBAL[line], 2), horizontalalignment='left', size='small', color='black')

# Configurar el gráfico
plt.title('Línea de tiempo de PUNT_GLOBAL por PERIODO en función de ESTU_DEPTO_RESIDE (Top 5 departamentos)')
plt.xlabel('Periodo')
plt.ylabel('Puntaje Global Promedio')

# Añadir una grilla de fondo para facilitar la lectura
plt.grid(True, which='both', linestyle='--', alpha=0.5)

# Configurar la leyenda para mejorar la presentación
plt.legend(title='Departamento de Residencia')

# Mostrar el gráfico
plt.show()

# %%
top5_cole = df_acumulado_saber_11.groupby('COLE_NOMBRE_ESTABLECIMIENTO')['PUNT_GLOBAL'].mean().nlargest(10)
top5_cole
# Out:
# COLE_NOMBRE_ESTABLECIMIENTO
# COL LA QUINTA DEL PUENTE              396.055556
# COL NUEVO CAMBRIDGE                   393.564356
# LIC CAMPO DAVID                       387.500000
# COLEGIO BILINGUE DIANA OESE           386.808989
# GIMN ALESSANDRO VOLTA                 372.885714
# COL LA COLINA                         371.681818
# COLEGIO LOS ÁNGELES                   368.719512
# COLEGIO PHILADELPHIA INTERNACIONAL    368.650000
# COL SAN JORGE DE INGLATERRA           368.116438
# COL NUEVO COLOMBO AMERICANO           366.982456
# Name: PUNT_GLOBAL, dtype: float64

# %%
# Distribución de los puntajes globales:

df_acumulado_saber_11['PUNT_GLOBAL'].hist(bins=30, figsize=(15, 5))
plt.title('Distribución de los puntajes globales')
plt.xlabel('Puntaje Global')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Puntajes globales por género:

puntajes_por_genero = df_acumulado_saber_11.groupby('ESTU_GENERO')['PUNT_GLOBAL'].mean()
print('Puntajes Globales Promedio por Género:')
puntajes_por_genero
# Out:
# Puntajes Globales Promedio por Género:
# ESTU_GENERO
# F             244.883692
# M             252.935929
# No_informa    250.606557
# Name: PUNT_GLOBAL, dtype: float64

# %%
# Top 5 municipios con puntajes globales más altos:

top5_municipios = df_acumulado_saber_11.groupby('ESTU_MCPIO_RESIDE')['PUNT_GLOBAL'].mean().nlargest(5)
print('Top 5 municipios con puntajes globales más altos:')
top5_municipios
# Out:
# Top 5 municipios con puntajes globales más altos:
# ESTU_MCPIO_RESIDE
# CONTRATACIÓN           287.775000
# PAIPA                  285.245018
# PALMAR                 282.500000
# ENVIGADO               282.153109
# SAN JOSÉ DE MIRANDA    281.818182
# Name: PUNT_GLOBAL, dtype: float64

# %%
puntaje_lectura = df_acumulado_saber_11.groupby('ESTU_DEDICACIONLECTURADIARIA')['PUNT_GLOBAL'].mean().sort_values(ascending=False)
puntaje_lectura
# Out:
# ESTU_DEDICACIONLECTURADIARIA
# >2h            266.533724
# 1h-2h          259.058055
# 30-60          257.876265
# <30            243.464511
# No lee         240.732053
# No responde    223.082666
# Name: PUNT_GLOBAL, dtype: float64

# %%
df_acumulado_saber_11.describe()
# Out:
#             PERIODO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# count  1.086317e+06          1.086317e+06      1.086317e+06      1.086317e+06
# mean   2.019851e+04          5.238752e+01      5.102646e+01      4.848017e+01
# std    5.469084e+00          1.047043e+01      1.198036e+01      1.081123e+01
# min    2.018100e+04          0.000000e+00      0.000000e+00      0.000000e+00
# 25%    2.019400e+04          4.500000e+01      4.200000e+01      4.000000e+01
# 50%    2.019400e+04          5.300000e+01      5.100000e+01      4.800000e+01
# 75%    2.020400e+04          6.000000e+01      5.900000e+01      5.600000e+01
# max    2.020400e+04          1.000000e+02      1.000000e+02      1.000000e+02
#
#        PUNT_SOCIALES_CIUDADANAS   PUNT_INGLES   PUNT_GLOBAL  ANIO_NACIMIENTO
# count              1.086317e+06  1.085928e+06  1.086317e+06     1.086317e+06
# mean               4.746889e+01  4.817472e+01  2.485626e+02     2.003829e+03
# ...

# %%
# Lista de columnas específicas para crear gráficos
selected_columns = [
                    'ESTU_GENERO', 'ESTU_TIENEETNIA', 'ESTU_DEPTO_RESIDE', 'FAMI_ESTRATOVIVIENDA',
                    'FAMI_PERSONASHOGAR',
                    'FAMI_CUARTOSHOGAR', 'FAMI_TIENEINTERNET', 'FAMI_TIENECOMPUTADOR', 'FAMI_TIENECONSOLAVIDEOJUEGOS',
                    'FAMI_NUMLIBROS', 'FAMI_SITUACIONECONOMICA', 'ESTU_DEDICACIONLECTURADIARIA',
                     'ESTU_DEDICACIONINTERNET',
                    'ESTU_HORASSEMANATRABAJA', 'ESTU_TIPOREMUNERACION', 'COLE_GENERO', 'COLE_NATURALEZA', 
                    'COLE_BILINGUE',
                    'COLE_CARACTER', 'COLE_AREA_UBICACION', 'COLE_JORNADA', 'ESTU_PRIVADO_LIBERTAD'
                ]

# Filtrar el DataFrame para incluir solo las columnas especificadas
df_filtered = df_acumulado_saber_11[selected_columns]

# Crear una figura con una cuadrícula de 5x5
fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(20, 20))

# Iterar sobre las columnas y los ejes para crear los gráficos
for idx, col in enumerate(df_filtered.columns):
    # Calcular la fila y columna en la cuadrícula
    row = idx // 5
    col_idx = idx % 5

    # Obtener el eje correspondiente en la cuadrícula
    ax = axes[row, col_idx]
    
    # Crear el gráfico de barras
    value_counts = df_filtered[col].value_counts()
    bars = ax.bar(value_counts.index.astype(str), value_counts.values)
    
    # Establecer el título del gráfico
    ax.set_title(f"Distribución de {col}")
  
    # Etiquetas de valores en las barras
    for bar in bars:
        ax.text(
            bar.get_x() + bar.get_width()/2,
            bar.get_height(),
            f'{bar.get_height():.0f}',
            ha = 'center',
            va = 'bottom'
        )

# Ajustar el diseño y mostrar los gráficos
plt.tight_layout()
plt.show()

# %% [markdown]
# Al evaluar visualmente el comportamiento de cada una de las variables, es esencial que la representación visual facilite una comprensión inmediata y contextualizada de los datos observados. Por lo tanto, las columnas:
#
# - ESTU_DEPTO_RESIDE
# - ESTU_TIPOREMUNERACION
# - COLE_CARACTER
# - COLE_JORNADA
#
# Serán excluidas de esta primera fase de visualización, pasaran a realizarce en otro bloque de visualización.

# %%
# Lista de columnas específicas para crear gráficos, excluyendo las columnas mencionadas
selected_columns = [
    'ESTU_GENERO', 'ESTU_TIENEETNIA', 'FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR',
    'FAMI_CUARTOSHOGAR', 'FAMI_TIENEINTERNET', 'FAMI_TIENECOMPUTADOR', 'FAMI_TIENECONSOLAVIDEOJUEGOS',
    'FAMI_NUMLIBROS', 'FAMI_SITUACIONECONOMICA', 'ESTU_DEDICACIONLECTURADIARIA', 'ESTU_DEDICACIONINTERNET',
    'ESTU_HORASSEMANATRABAJA', 'COLE_GENERO', 'COLE_NATURALEZA', 'COLE_BILINGUE', 
    'COLE_AREA_UBICACION', 'ESTU_PRIVADO_LIBERTAD'
]

# Filtrar el DataFrame para incluir solo las columnas especificadas
df_filtered = df_acumulado_saber_11[selected_columns]

# Crear una figura con una cuadrícula de 3 columnas por 6 filas
fig, axes = plt.subplots(nrows=6, ncols=3, figsize=(15, 25))

# Iterar sobre las columnas y los ejes para crear los gráficos
for idx, col in enumerate(df_filtered.columns):
    # Calcular la fila y columna en la cuadrícula
    row = idx // 3
    col_idx = idx % 3
    
    # Obtener el eje correspondiente en la cuadrícula
    ax = axes[row, col_idx]
    
    # Crear el gráfico de barras
    value_counts = df_filtered[col].value_counts()
    bars = ax.bar(value_counts.index.astype(str), value_counts.values)
    
    # Establecer el título del gráfico
    ax.set_title(f"Distribución de {col}")
    
    # Etiquetas de valores en las barras
    for bar in bars:
        ax.text(
            bar.get_x() + bar.get_width() / 2,
            bar.get_height(),
            f'{bar.get_height():.0f}',  # Formatear el valor como entero
            ha='center',
            va='bottom'
        )

# Ajustar el diseño y mostrar los gráficos
plt.tight_layout()
plt.show()

# %%
# Lista de columnas específicas para crear gráficos, incluyendo las columnas mencionadas que se excluyeron
selected_columns = [
                    'ESTU_DEPTO_RESIDE', 'ESTU_TIPOREMUNERACION',
                    'COLE_CARACTER', 'COLE_JORNADA'
]

# Filtrar el DataFrame para incluir solo las columnas especificadas
df_filtered = df_acumulado_saber_11[selected_columns]

# Crear una figura con una cuadrícula de 3 columnas por 6 filas
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 8))

# Iterar sobre las columnas y los ejes para crear los gráficos
for idx, col in enumerate(df_filtered.columns):
    # Calcular la fila y columna en la cuadrícula
    row = idx // 2
    col_idx = idx % 2
    
    # Obtener el eje correspondiente en la cuadrícula
    ax = axes[row, col_idx]
    
    # Crear el gráfico de barras
    value_counts = df_filtered[col].value_counts()
    bars = ax.bar(value_counts.index, value_counts.values)
    
    # Establecer el título del gráfico
    ax.set_title(f"Distribución de {col}")
    
    # Etiquetas de valores en las barras
    for bar in bars:
        ax.text(
            bar.get_x() + bar.get_width() / 2,
            bar.get_height(),
            f'{bar.get_height():.0f}',  # Formatear el valor como entero
            ha='center',
            va='bottom'
        )

# Ajustar el diseño y mostrar los gráficos
plt.tight_layout()
plt.show()

# %% [markdown]
# Visualización de la distribución de variables numéricas:
#
# - Objetivo: Utilizar histogramas, diagramas de densidad y boxplots para visualizar la distribución de las variables numéricas (como PUNT_GLOBAL, PUNT_LECTURA_CRITICA, PUNT_MATEMATICAS, etc.).
#
# - Aplicación: Esto te ayudará a identificar posibles valores atípicos y patrones en la distribución de los datos.

# %%
# Función para visualizar la distribución de variables numéricas
def visualizar_distribucion_variables_numericas(df, variables_numericas):
    # Crear una figura con una cuadrícula de 3 columnas y 2 filas
    fig, axes = plt.subplots(2, 3, figsize=(15,8))
    axes = axes.flatten() # Aplanar la cuadrícula de ejes para iterar fácilmente
    
    # Iterar sobre cada variable numérica y el correspondiente eje
    for i, variable in enumerate(variables_numericas):
        # Crear un histograma con una curva de densidad superpuesta para cada variable numérica
        ax = axes[i]
        sns.histplot(df[variable], kde=True, color='blue', bins=30, ax=ax)
            
        # Añadir etiquetas de frecuencia en las barras
        for patch in ax.patches:
            height = patch.get_height()
            ax.text(patch.get_x() + patch.get_width() / 2, height, f'{height:.0f}', ha='center', va='bottom', fontsize=8)
       
        # Configurar el título y etiquetas
        ax.set_title(f'Distribución de la variable {variable}')
        ax.set_xlabel(variable)
        ax.set_ylabel('Frecuencia')

    # Eliminar los ejes sobrantes si hay menos variables que subtramas
    for j in range(len(variables_numericas), len(axes)):
        fig.delaxes(axes[j])
    
    # Ajustar el diseño y mostrar la figura
    plt.tight_layout()
    plt.show()


# Lista de variables numéricas para analizar
variables_numericas = ['PUNT_GLOBAL', 'PUNT_LECTURA_CRITICA', 'PUNT_MATEMATICAS', 'PUNT_C_NATURALES', 'PUNT_SOCIALES_CIUDADANAS', 'PUNT_INGLES']

# Llamar a la función para visualizar la distribución de las variables numéricas
visualizar_distribucion_variables_numericas(df_acumulado_saber_11, variables_numericas)

# %%
# Lista de columnas numéricas en el DataFrame
numeric_colums = df_acumulado_saber_11.select_dtypes(include='number').columns

# Crear una figura con una cuadrícula de 4 columnas por 2 filas
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(16, 8))

# Iterar sobre las columnas numéricas y los ejes para crear los diagramas de cajas
for idx, col in enumerate(numeric_colums):
    # Calcular la fila y columna en la cuadrícula
    row = idx // 4
    col_idx = idx % 4
   
    # Obtener el eje correspondiente en la cuadrícula
    ax  =axes[row, col_idx]
    
    # Crear el diagrama de cajas con color azul
    df_acumulado_saber_11.boxplot(
        column=col,
        ax=ax,
        patch_artist = True, # Permite personalizar el color de las cajas
        boxprops = dict(facecolor='blue') # Color de las cajas (azul)
    )
    
    # Establecer el título del gráfico
    ax.set_title(f"Diagrama de caja para {col}")
    
    
    # Mejorar la visualización
    ax.set_xlabel("")  # Ocultar el nombre del eje x para una presentación más limpia
    ax.set_ylabel("")  # Ocultar el nombre del eje y para una presentación más limpia

# Ajustar el diseño y mostrar los gráficos
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Análisis de relaciones entre variables

# %% [markdown]
# Elegir las variables adecuadas para una matriz de correlación es crucial para obtener información valiosa y evitar resultados irrelevantes o confusos. En el caso del conjunto de datos df_acumulado_saber_11, se deben considerar diversos aspectos para seleccionar las variables más pertinentes:
#
# `1. Objetivo del análisis:`
#
# - ¿Se busca identificar relaciones entre variables que expliquen el rendimiento académico? En este caso, las variables de rendimiento académico (PUNT_LECTURA_CRITICA, PUNT_MATEMATICAS, PUNT_C_NATURALES, PUNT_SOCIALES_CIUDADANAS, PUNT_INGLES, PUNT_GLOBAL) serían las más relevantes.
#
# - ¿Se quiere analizar la influencia de factores socioeconómicos o demográficos en el rendimiento académico? En este caso, variables como FAMI_ESTRATOVIVIENDA, FAMI_EDUCACIONPADRE, FAMI_EDUCACIONMADRE, FAMI_TIENEINTERNET, FAMI_TIENECOMPUTADOR, FAMI_TIENECONSOLAVIDEOJUEGOS, COLE_GENERO, COLE_NATURALEZA, COLE_BILINGUE, COLE_CARACTER, COLE_AREA_UBICACION, COLE_JORNADA, ESTU_PRIVADO_LIBERTAD, ANIO_NACIMIENTO podrían ser de interés.
#
# `2. Tipo de variable:`
#
# - Variables cualitativas: No son adecuadas para la correlación lineal, ya que no representan valores numéricos. Sin embargo, se pueden analizar por separado utilizando otras técnicas como tablas de contingencia o pruebas de Chi-cuadrado. En este conjunto de datos, las variables cualitativas incluyen ESTU_TIPODOCUMENTO, ESTU_GENERO, ESTU_PAIS_RESIDE, ESTU_TIENEETNIA, FAMI_TRABAJOLABORPADRE, FAMI_TRABAJOLABORMADRE, COLE_GENERO, COLE_NATURALEZA, COLE_BILINGUE, COLE_CARACTER, COLE_AREA_UBICACION, COLE_JORNADA, ESTU_PRIVADO_LIBERTAD.
#
# - Variables cuantitativas: Son las idóneas para la correlación lineal, ya que representan valores numéricos que pueden ser medidos y comparados. En este conjunto de datos, las variables cuantitativas incluyen PERIODO, PUNT_LECTURA_CRITICA, PUNT_MATEMATICAS, PUNT_C_NATURALES, PUNT_SOCIALES_CIUDADANAS, PUNT_INGLES, PUNT_GLOBAL, ANIO_NACIMIENTO.
#
# `3. Redundancia de información:`
#
# - Se deben evitar variables que proporcionan información redundante o altamente correlacionada entre sí.
#
# Considerando estos aspectos, una selección adecuada de variables para la matriz de correlación en df_acumulado_saber_11 podría ser:
#
# - Variables de rendimiento académico: PUNT_LECTURA_CRITICA, PUNT_MATEMATICAS, PUNT_C_NATURALES, PUNT_SOCIALES_CIUDADANAS, PUNT_INGLES.
#
# - Variables socioeconómicas o demográficas (opcionales): FAMI_ESTRATOVIVIENDA, FAMI_EDUCACIONPADRE, FAMI_EDUCACIONMADRE, ANIO_NACIMIENTO (considerando que esta variable es cuantitativa).
#
# `Es importante recordar que la selección final de variables dependerá del objetivo específico del análisis y de las características del conjunto de datos. Se recomienda realizar un análisis exploratorio previo para comprender mejor la distribución y las relaciones entre las variables antes de crear la matriz de correlación.`

# %%
df_acumulado_saber_11.columns
# Out:
# Index(['ESTU_TIPODOCUMENTO', 'ESTU_NACIONALIDAD', 'ESTU_GENERO', 'PERIODO',
#        'ESTU_CONSECUTIVO', 'ESTU_PAIS_RESIDE', 'ESTU_TIENEETNIA',
#        'ESTU_DEPTO_RESIDE', 'ESTU_MCPIO_RESIDE', 'FAMI_ESTRATOVIVIENDA',
#        'FAMI_PERSONASHOGAR', 'FAMI_CUARTOSHOGAR', 'FAMI_EDUCACIONPADRE',
#        'FAMI_EDUCACIONMADRE', 'FAMI_TRABAJOLABORPADRE',
#        'FAMI_TRABAJOLABORMADRE', 'FAMI_TIENEINTERNET', 'FAMI_TIENECOMPUTADOR',
#        'FAMI_TIENECONSOLAVIDEOJUEGOS', 'FAMI_NUMLIBROS',
#        'FAMI_SITUACIONECONOMICA', 'ESTU_DEDICACIONLECTURADIARIA',
#        'ESTU_DEDICACIONINTERNET', 'ESTU_HORASSEMANATRABAJA',
#        'ESTU_TIPOREMUNERACION', 'COLE_NOMBRE_ESTABLECIMIENTO', 'COLE_GENERO',
#        'COLE_NATURALEZA', 'COLE_BILINGUE', 'COLE_CARACTER',
#        'COLE_AREA_UBICACION', 'COLE_JORNADA', 'ESTU_PRIVADO_LIBERTAD',
#        'PUNT_LECTURA_CRITICA', 'PUNT_MATEMATICAS', 'PUNT_C_NATURALES',
#        'PUNT_SOCIALES_CIUDADANAS', 'PUNT_INGLES', 'PUNT_GLOBAL',
# ...

# %%
# Selección de variables de rendimiento académico
variables_rendimiento = ['PUNT_LECTURA_CRITICA', 'PUNT_MATEMATICAS', 'PUNT_C_NATURALES',
                        'PUNT_SOCIALES_CIUDADANAS', 'PUNT_INGLES', 'PUNT_GLOBAL']

# Cálculo de la matriz de correlación
matriz_correlacion = df_acumulado_saber_11[variables_rendimiento].corr()

# Visualización de la matriz de correlación
matriz_correlacion
# Out:
#                           PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# PUNT_LECTURA_CRITICA                  1.000000          0.725964
# PUNT_MATEMATICAS                      0.725964          1.000000
# PUNT_C_NATURALES                      0.736469          0.775557
# PUNT_SOCIALES_CIUDADANAS              0.791428          0.719038
# PUNT_INGLES                           0.655225          0.648060
# PUNT_GLOBAL                           0.893858          0.892039
#
#                           PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  \
# PUNT_LECTURA_CRITICA              0.736469                  0.791428
# PUNT_MATEMATICAS                  0.775557                  0.719038
# PUNT_C_NATURALES                  1.000000                  0.772713
# PUNT_SOCIALES_CIUDADANAS          0.772713                  1.000000
# PUNT_INGLES                       0.696437                  0.661628
# PUNT_GLOBAL                       0.908027                  0.909826
#
# ...

# %%
# Conversión de la matriz de correlación a DataFrame


# Generación del gráfico de calor


# Personalización del gráfico


# Rotación de las etiquetas del eje x para mejorar la legibilidad


# Visualización del gráfico de calor

# %% [markdown]
# Observaciones de la correlación:
#
# - PUNT_LECTURA_CRITICA tiene una correlación positiva moderada con todas las demás variables de rendimiento académico. Esto significa que, a medida que aumenta el puntaje en lectura crítica, tienden a aumentar los puntajes en las demás áreas (matemáticas, ciencias naturales, sociales y ciudadanas, inglés).
#
# - Es importante tener en cuenta que la correlación no implica causalidad. El hecho de que dos variables estén correlacionadas no significa que una cause directamente a la otra.
#
# - Se deben realizar análisis adicionales, como pruebas de hipótesis o modelos estadísticos, para comprender mejor las relaciones entre las variables y establecer posibles relaciones causales.
#
# - En general, se observa que las variables de rendimiento académico están correlacionadas entre sí de manera positiva, lo que sugiere que el rendimiento en un área tiende a estar asociado con un buen rendimiento en otras áreas. Sin embargo, es importante tener en cuenta que la correlación no implica causalidad. Es decir, que dos variables estén correlacionadas no significa que una cause directamente la otra. Es posible que existan otros factores que influyan en el rendimiento académico de manera similar.

# %%
# Crear un dataframe que contenga solo las columnas relevantes

# Convertir la columna ESTU_DEDICACIONLECTURADIARIA a variables numéricas


# Calcular la matriz de correlación


# Visualizar la matriz de correlación utilizando un mapa de calor


# Configurar el gráfico

# %% [markdown]
# # Despliegue Técnico perfilamiento

# %%
# !pip install -U pip
# !pip install fastcore==1.5.29

# %% [markdown]
# Mascaras:
#
# Son representaciones, donde:
#
# - Usa L para referirse a letras
# - Usa D para referirse a digitos
# - Usa S para referirse a espacios
